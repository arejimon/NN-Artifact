# %%
# !python ../inference.py --subject-dir F:\processedwithhilite\DOSEESC_UM04 --study-date 03.28.2018 --mc-passes=5
# Out:
# QMAP4 override: 38 artifact voxels reclassified as good
# INFO | Output directory: F:\processedwithhilite\DOSEESC_UM04\artifactremoval\nn_artifact_output
# INFO | Loading MIDAS subject from F:\processedwithhilite\DOSEESC_UM04\subject.xml
# INFO | Processing study: 03/28/2018
# INFO | Loaded spectra via NNFitDataset
# INFO | Loaded water via study.siref()
# INFO | Spectral data shape: Z=32, X=64, Y=64, S=512
# INFO | Found FLAIR image: F:\processedwithhilite\DOSEESC_UM04\mri\03.28.2018_autoseg\preprocessed_flair.nii.gz
# INFO | Found FLAIR seg: F:\processedwithhilite\DOSEESC_UM04\mri\03.28.2018_autoseg\binary_segmentation_flair_128.nii.gz
# INFO | Loaded cerebellum/brainstem mask from F:\processedwithhilite\DOSEESC_UM04\ants\segmentations_03_28_2018.nii.gz
# INFO | Loaded QMAP from MIDAS
# INFO | Loading Normal-Brain CNN model from E:\code\NN-Artifact\models\NNArtifact_tf2
# ...

# %%
# !python test_validate.py --subject-dir F:\processedwithhilite\DOSEESC_UM04 --study-date 03.28.2018
# Out:
# Output shape: (32, 64, 64)
# Brain mask voxels: 12275
#
# ...
# TEST 1: Weight map structure
# ...
#   Unique weights: [0.   0.25 0.5  0.75 1.  ]
#   Expected:       [0.0, 0.25, 0.5, 0.75, 1.0]
# PASS: Weight values are valid shell values
#   Nonzero weight voxels: 2515
#   w=1.0 (inside gate): 798
#   w=0.75 (shell 1):    393
#   w=0.50 (shell 2):    531
#   w=0.25 (shell 3):    793
#   w=0.0  (outside):    128557
#
# ...
# TEST 2: Hybrid = w * Tumor_CNN + (1-w) * Normal_Brain
# ...
#   Max diff (non-QMAP voxels): 0.00000083
#   Mean diff (non-QMAP voxels): 0.00000000
#   QMAP-overridden voxels:      138
# PASS: Blend formula verified
#
# ...
# TEST 3: QMAP==4 override (within FLAIR seg)
# ...
#   QMAP==4 voxels in brain: 9539
#   QMAP4 voxels set to good (artifact->good): 138
#   QMAP4 voxels with hybrid=0:                5252
# PASS: QMAP4 override applied within FLAIR seg
#
# ...
# TEST 4: Value ranges
# ...
#   hybrid        : [0.000000, 1.000000]  OK
#   tumor_cnn     : [0.000000, 1.000000]  OK
# ...
